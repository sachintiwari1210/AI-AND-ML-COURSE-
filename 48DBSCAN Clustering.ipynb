# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN

# %% [markdown]
# ##### CREATE THE DATASET

# %%
# Step 1: Create a sample dataset
x,y = make_blobs(n_samples=300, centers=4,
                  cluster_std=0.68, random_state=0)

# %%
x.shape
# Out:
# (300, 2)

# %%
plt.xlabel('Feature-1')
plt.ylabel('Featue-2')
plt.scatter(x[:,0], x[:,1])

# %% [markdown]
# ##### CREATE TEH OBJECT

# %%
# Step 2: Apply DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
clusters = dbscan.fit_predict(x)

# %%
clusters
# Out:
# array([-1,  0,  1,  0,  3, -1,  2,  1,  0,  0,  2,  0,  1,  0,  3,  1,  1,
#         3,  2,  2,  3,  3,  1,  2,  2, -1,  3,  1, -1,  1,  0,  0,  1,  0,
#         0,  0,  0,  0,  2,  3,  1,  2, -1,  1,  2,  2,  0,  2,  0,  3,  2,
#         3,  0,  3,  3,  2, -1,  2,  0,  3,  0,  1, -1,  2,  2,  2,  0,  3,
#         0,  2,  1,  2,  0,  2,  2,  0,  2,  1,  3,  0,  3,  1,  3,  3,  0,
#         1,  3,  1, -1,  0,  1,  3,  0,  2,  2,  1,  3,  3, -1, -1,  0,  3,
#         0,  3,  1,  3, -1,  1,  0,  1,  2,  2,  3,  0,  3, -1,  0,  3,  3,
#         1,  2,  3,  2,  3,  3,  3,  3,  2,  3,  2,  0,  2,  2, -1,  0,  2,
#         2,  0,  1,  0,  0,  2,  1, -1,  4,  2,  0,  1,  0,  0,  0,  1, -1,
#         1,  3,  2,  0,  2,  3,  1,  0,  1,  1,  3,  1,  2, -1,  1,  3,  1,
#         1,  0,  3,  4, -1,  0,  3,  3,  1,  2,  3,  1,  2,  2,  1,  1,  1,
#         1,  3,  0,  1,  2,  1,  1,  2,  2,  2,  1,  2,  0,  1,  2,  3,  2,
#         1, -1,  2,  0,  1,  0,  1,  2,  1,  1,  0,  2,  2,  3, -1,  1,  0,
#         3,  3,  2,  3,  2,  1,  0,  0,  4,  1,  0,  1,  3,  2,  1,  3,  2,
#         0,  2,  3,  1, -1,  0,  0,  0,  0,  2,  2, -1,  4,  2,  3,  1,  2,
#         2,  1,  3,  3,  0,  1,  1,  2,  3,  0,  2,  1,  0,  1,  3,  3,  2,
#         2, -1, -1,  3,  3,  4,  0,  0,  3,  3,  1,  3,  3, -1,  0,  2,  0,
#         1, -1,  3,  0,  0,  0,  3,  3,  1, -1,  2], dtype=int64)

# %% [markdown]
# ##### VISUALIZE THE CLUSTER

# %%
plt.xlabel('Feature-1')
plt.ylabel('Feature-2')
plt.scatter(x[:,0], x[:,1], c = clusters)
