# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0,50,0.05)

# %%
y = np.sin(x)
z = np.cos(x)

# %%
plt.figure(figsize=(16,9))
plt.plot(x, y)
plt.plot(x, z)

# %% [markdown]
# ##### Rotation using Function

# %%
import cv2

#Load the image
image = cv2.imread("images/lenna.png")

# Rotate the image 45 degrees clockwise
rotated_image = cv2.rotate(image, cv2.ROTATE_180)

# Show the roated image
cv2.imshow("Rotated Image", rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# load the image
image = cv2.imread("images/lenna.png")

# Define the centre point and rotation angle
center = (image.shape[1] // 2, image.shape[0] // 2)
angle = -60

# Create the rotation matrix 
rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)

# Apply the rotation ysing warpAlline
rotated_image = cv2.warpAffine(image, rotation_matrix,
                               (image.shape[1], image.shape[0]))

# Show the rotated image
cv2.imshow("Rptated Image", rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# load teh image
image = cv2.imread("images/lenna.png")

# Define the centre point and rotation angle
center = (image.shape[1] // 2, image.shape[0] // 2)
angle = -60

# Create the rotation matrix 
rotation_matrix = cv2.getRotationMatrix2D((100,100), angle, 1.0)

# Apply the rotation ysing warpAlline
rotated_image = cv2.warpAffine(image, rotation_matrix,
                               (image.shape[1], image.shape[0]))

# Show the rotated image
cv2.imshow("Rptated Image", rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Rotation using PIL

# %%
from PIL import Image
image = Image.open('images/lenna.png')

# %%
converted_img = image.transpose(Image.ROTATE_180)
converted_img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
