# %%
import cv2
import matplotlib.pyplot as plt

# %%
vid = cv2.VideoCapture('images/robots.mp4')

# %%
vid
# Out:
# < cv2.VideoCapture 0000018E623F2570>

# %%
ret, frame = vid.read()

# %%
ret
# Out:
# True

# %%
frame.size
# Out:
# 1228800

# %%
frame.dtype
# Out:
# dtype('uint8')

# %%
frame.shape
# Out:
# (640, 640, 3)

# %%
cv2.imshow('Frame', frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
width = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
frames = int(vid.get(cv2.CAP_PROP_FRAME_COUNT))
fps = int(vid.get(cv2.CAP_PROP_FPS))

# %%
print('Video Resolutiion:', height,width)
print('Total Frames:', frames)
print('FPS:', fps)
# Out:
# Video Resolutiion: 640 640
# Total Frames: 1799
# FPS: 30

# %%
vid = cv2.VideoCapture('images/robots.mp4')
while True:
    ret, frame = vid.read()
    if not ret:
        break
    # Process the frame (e.g., apply filters, detect objects)
    cv2.imshow('Video', frame)
    if cv2.waitKey(5) == ord('q'):
        break

cv2.destroyAllWindows()

# %%
vid = cv2.VideoCapture('images/robots.mp4')

# get the first frame and see if successful
success, frame = vid.read()
# initiate count 
count = 1
# keep extracting frames as long as success is True
while success:
    cv2.imwrite(f'video_frames/{count}.jpg', frame)
    success, frame = vid.read()
    count += 1

# %%
img800 = plt.imread('video_frames/800.jpg')
plt.imshow(img800)

# %%
img1000 = plt.imread('video_frames/1000.jpg')
plt.imshow(img1000)

# %%
img200 = plt.imread('video_frames/200.jpg')
plt.imshow(img200)

# %%
timestamp = '00:00:43'

# %%
timestamp.split(':')
# Out:
# ['00"00', '43.00']

# %%
# get frame at a specific timestamp
timestamp = '00:00:43.00'
hours, minutes, seconds = [float(i) for i in timestamp.split(':')]
print(hours, minutes, seconds)
# Out:
# 0.0 0.0 43.0

# %%
# get number of frames up to timestamp
trigger_frame = hours * 3600 * fps + minutes * 60 * fps + seconds * fps
print(frames, trigger_frame)
# Out:
# 1799 1290.0

# %%
# Go to frame selected by timestamp
vid.set(1, trigger_frame)
success, frame = vid.read()

# save the frame into an image file 
if success:
    cv2.imwrite('screen.jpg', frame)

# %%
cap = cv2.VideoCapture(0)

# %%
cap.isOpened()
# Out:
# False

# %%
success, frame = cap.read()

# %%
cap.release()

# %%
cv2.imwrite('screen.jpg', frame)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 cv2.imwrite('screen.jpg', frame)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:798: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
