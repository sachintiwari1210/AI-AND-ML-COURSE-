# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\rajesh\anaconda3\lib\site-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\rajesh\anaconda3\lib\site-packages (from mlxtend) (1.11.4)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\rajesh\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\rajesh\anaconda3\lib\site-packages (from mlxtend) (2.1.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\rajesh\anaconda3\lib\site-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\rajesh\anaconda3\lib\site-packages (from mlxtend) (3.8.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\rajesh\anaconda3\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rajesh\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rajesh\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rajesh\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rajesh\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rajesh\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rajesh\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rajesh\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rajesh\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajesh\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rajesh\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rajesh\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\rajesh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### CREATE THE DATASET

# %%
dataset = [
    ['Apple', 'Beer', 'Rice','Chicken'],
    ['Apple', 'Beer', 'Rice'],
    ['Apple', 'Beer'],
    ['Apple', 'Peer',],
    ['Milk', 'Beer', 'Rice','Chicken'],
    ['Milk', 'Beer', 'Rice'],
    ['Milk', 'Beer'],
    ['Milk', 'Peer'],
]

# %%
dataset
# Out:
# [['Apple', 'Beer', 'Rice', 'Chicken'],
#  ['Apple', 'Beer', 'Rice'],
#  ['Apple', 'Beer'],
#  ['Apple', 'Peer'],
#  ['Milk', 'Beer', 'Rice', 'Chicken'],
#  ['Milk', 'Beer', 'Rice'],
#  ['Milk', 'Beer'],
#  ['Milk', 'Peer']]

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

# %%
te = TransactionEncoder()
encoded = te.fit_transform(dataset)

# %%
encoded
# Out:
# array([[ True,  True,  True, False, False,  True],
#        [ True,  True, False, False, False,  True],
#        [ True,  True, False, False, False, False],
#        [ True, False, False, False,  True, False],
#        [False,  True,  True,  True, False,  True],
#        [False,  True, False,  True, False,  True],
#        [False,  True, False,  True, False, False],
#        [False, False, False,  True,  True, False]])

# %%
te.columns_
# Out:
# ['Apple', 'Beer', 'Chicken', 'Milk', 'Peer', 'Rice']

# %%
df = pd.DataFrame(encoded, columns=te.columns_)

# %%
df
# Out:
#    Apple   Beer  Chicken   Milk   Peer   Rice
# 0   True   True     True  False  False   True
# 1   True   True    False  False  False   True
# 2   True   True    False  False  False  False
# 3   True  False    False  False   True  False
# 4  False   True     True   True  False   True
# 5  False   True    False   True  False   True
# 6  False   True    False   True  False  False
# 7  False  False    False   True   True  False

# %%
from mlxtend.frequent_patterns import fpgrowth, association_rules

# %%
# 1. Find freqent itemset
freq_itemset = fpgrowth(df, min_support=0.25, use_colnames=True)

# %%
freq_itemset
# Out:
#     support               itemsets
# 0     0.750                 (Beer)
# 1     0.500                 (Rice)
# 2     0.500                (Apple)
# 3     0.250              (Chicken)
# 4     0.250                 (Peer)
# 5     0.500                 (Milk)
# 6     0.500           (Beer, Rice)
# 7     0.375          (Beer, Apple)
# 8     0.250          (Rice, Apple)
# 9     0.250    (Beer, Rice, Apple)
# 10    0.250        (Rice, Chicken)
# 11    0.250        (Beer, Chicken)
# 12    0.250  (Beer, Rice, Chicken)
# 13    0.375           (Beer, Milk)
# 14    0.250           (Milk, Rice)
# 15    0.250     (Beer, Milk, Rice)

# %%
rules = association_rules(freq_itemset, metric='confidence', min_threshold=0.5)

# %%
rules.shape
# Out:
# (28, 10)

# %% [raw]
# rules

# %%
rules = rules[['antecedents','consequents','support','confidence']]

# %%
rules
# Out:
#         antecedents      consequents  support  confidence
# 0            (Beer)           (Rice)    0.500    0.666667
# 1            (Rice)           (Beer)    0.500    1.000000
# 2            (Beer)          (Apple)    0.375    0.500000
# 3           (Apple)           (Beer)    0.375    0.750000
# 4            (Rice)          (Apple)    0.250    0.500000
# 5           (Apple)           (Rice)    0.250    0.500000
# 6      (Beer, Rice)          (Apple)    0.250    0.500000
# 7     (Beer, Apple)           (Rice)    0.250    0.666667
# 8     (Rice, Apple)           (Beer)    0.250    1.000000
# 9            (Rice)    (Beer, Apple)    0.250    0.500000
# 10          (Apple)     (Beer, Rice)    0.250    0.500000
# 11           (Rice)        (Chicken)    0.250    0.500000
# 12        (Chicken)           (Rice)    0.250    1.000000
# 13        (Chicken)           (Beer)    0.250    1.000000
# 14     (Beer, Rice)        (Chicken)    0.250    0.500000
# 15  (Beer, Chicken)           (Rice)    0.250    1.000000
# 16  (Rice, Chicken)           (Beer)    0.250    1.000000
# 17           (Rice)  (Beer, Chicken)    0.250    0.500000
# 18        (Chicken)     (Beer, Rice)    0.250    1.000000
# 19           (Beer)           (Milk)    0.375    0.500000
# 20           (Milk)           (Beer)    0.375    0.750000
# 21           (Milk)           (Rice)    0.250    0.500000
# 22           (Rice)           (Milk)    0.250    0.500000
# 23     (Beer, Milk)           (Rice)    0.250    0.666667
# 24     (Beer, Rice)           (Milk)    0.250    0.500000
# 25     (Milk, Rice)           (Beer)    0.250    1.000000
# 26           (Milk)     (Beer, Rice)    0.250    0.500000
# 27           (Rice)     (Beer, Milk)    0.250    0.500000

# %% [markdown]
# ##### SHORT THE RULES

# %%
# By confidence decending order

# %%
rules.sort_values(by=['confidence','support'], ascending=False)
# Out:
#         antecedents      consequents  support  confidence
# 1            (Rice)           (Beer)    0.500    1.000000
# 8     (Rice, Apple)           (Beer)    0.250    1.000000
# 12        (Chicken)           (Rice)    0.250    1.000000
# 13        (Chicken)           (Beer)    0.250    1.000000
# 15  (Beer, Chicken)           (Rice)    0.250    1.000000
# 16  (Rice, Chicken)           (Beer)    0.250    1.000000
# 18        (Chicken)     (Beer, Rice)    0.250    1.000000
# 25     (Milk, Rice)           (Beer)    0.250    1.000000
# 3           (Apple)           (Beer)    0.375    0.750000
# 20           (Milk)           (Beer)    0.375    0.750000
# 0            (Beer)           (Rice)    0.500    0.666667
# 7     (Beer, Apple)           (Rice)    0.250    0.666667
# 23     (Beer, Milk)           (Rice)    0.250    0.666667
# 2            (Beer)          (Apple)    0.375    0.500000
# 19           (Beer)           (Milk)    0.375    0.500000
# 4            (Rice)          (Apple)    0.250    0.500000
# 5           (Apple)           (Rice)    0.250    0.500000
# 6      (Beer, Rice)          (Apple)    0.250    0.500000
# 9            (Rice)    (Beer, Apple)    0.250    0.500000
# 10          (Apple)     (Beer, Rice)    0.250    0.500000
# 11           (Rice)        (Chicken)    0.250    0.500000
# 14     (Beer, Rice)        (Chicken)    0.250    0.500000
# 17           (Rice)  (Beer, Chicken)    0.250    0.500000
# 21           (Milk)           (Rice)    0.250    0.500000
# 22           (Rice)           (Milk)    0.250    0.500000
# 24     (Beer, Rice)           (Milk)    0.250    0.500000
# 26           (Milk)     (Beer, Rice)    0.250    0.500000
# 27           (Rice)     (Beer, Milk)    0.250    0.500000

# %% [markdown]
# ##### Filter he rules

# %%
nrules = rules[rules['confidence'] > 0.5]

# %%
nrules.shape
# Out:
# (13, 4)

# %%
nrules[nrules['antecedents'] == {'Apple','Beer'}]['consequents']
# Out:
# 7    (Rice)
# Name: consequents, dtype: object

# %% [markdown]
# ##### EXPORT THE RULES

# %%
nrules.to_csv('rules1.csv', index = False)
